# %%
import pandas as pd

# Read data from CSV and XLS files
data_csv = pd.read_csv(r'C:\Users\ABC\Desktop\ml\.ipynb_checkpoints\Assignment1\admission.csv')


# b) Find Shape of Data
print("Shape of CSV Data:", data_csv.shape)

# c) Find Missing Values
print("\nMissing Values in CSV Data:\n", data_csv.isnull().sum())

# d) Find Data Type of Each Column
print("\nData Types of Each Column:\n", data_csv.dtypes)

# e) Finding out Zeros
print("\nCount of Zeros in Each Column:\n", (data_csv == 0).sum())

# f) Indexing and Selecting Data, Sorting Data
# Select first 5 rows
print("\nFirst 5 Rows:\n", data_csv.head())

# Sort by a column (replace 'ColumnName' with actual column name)
# data_csv_sorted = data_csv.sort_values(by='ColumnName')
# print("\nSorted Data:\n", data_csv_sorted.head())

# g) Describe Attributes of Data
print("\nData Description:\n", data_csv.describe())

# Checking Data Types of Each Column
print("\nData Types:\n", data_csv.dtypes)

# h) Counting Unique Values of Data
print("\nUnique Values Count:\n", data_csv.nunique())

# Format of Each Column
print("\nColumn Names and Data Types:\n", data_csv.info())

# Converting Data Type (e.g., from float to int)
# Replace 'ColumnName' with actual column name
# data_csv['ColumnName'] = data_csv['ColumnName'].astype(int)

# Converting Data Type (e.g., from int to float)
# data_csv['ColumnName'] = data_csv['ColumnName'].astype(float)

print("\nData Types after Conversion:\n", data_csv.dtypes)
# Out:
# Shape of CSV Data: (500, 9)
#
# Missing Values in CSV Data:
#  Serial No.           0
# GRE Score            0
# TOEFL Score          0
# University Rating    0
# SOP                  0
# LOR                  0
# CGPA                 0
# Research             0
# Chance of Admit      0
# dtype: int64
#
# Data Types of Each Column:
#  Serial No.             int64
# GRE Score              int64
# TOEFL Score            int64
# University Rating      int64
# SOP                  float64
# LOR                  float64
# CGPA                 float64
# Research               int64
# Chance of Admit      float64
# dtype: object
#
# Count of Zeros in Each Column:
#  Serial No.             0
# GRE Score              0
# TOEFL Score            0
# University Rating      0
# SOP                    0
# LOR                    0
# CGPA                   0
# Research             220
# Chance of Admit        0
# dtype: int64
#
# First 5 Rows:
# ...
